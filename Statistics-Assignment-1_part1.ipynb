# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
#  Import **NumPy**, **SciPy**, and **Pandas**

# %%
import numpy as np
import scipy
from scipy import stats
import pandas as pd

# %% [markdown]
#  Randomly generate 1,000 samples from the normal distribution using `np.random.normal()`(mean = 100, standard deviation = 15)

# %%
samples = np.random.normal(100, 15, 1000)

# %% [markdown]
# Compute the **mean**, **median**, and **mode**

# %%
mean = np.mean(samples)
print("Mean :", mean)

median = np.median(samples)
print("Median :", median)

mode = stats.mode(samples)
print("Mode :", mode)
# Out:
# Mean : 100.16041021624557
# Median : 100.74471663131922
# Mode : ModeResult(mode=array([50.58908499]), count=array([1]))

# %% [markdown]
# Compute the **min**, **max**, **Q1**, **Q3**, and **interquartile range**

# %%
min_1 = np.min(samples)
print("Min :", min_1)

max_1 = np.max(samples)
print("Max :", max_1)

q1 = np.percentile(samples, 25)
print("Q1 :", q1)

q3 = np.percentile(samples, 75)
print("Q3 :", q3)

iqr = stats.iqr(samples)
print("IQR :", iqr)
# Out:
# Min : 50.58908499448578
# Max : 151.5667534851139
# Q1 : 89.92902057595396
# Q3 : 109.92183649246357
# IQR : 19.992815916509613

# %% [markdown]
# Compute the **variance** and **standard deviation**

# %%
variance = np.var(samples)
print("Variance :", variance)

std_dev = np.std(samples)
print("Std :", std_dev)
# Out:
# Variance : 223.777786561771
# Std : 14.959204075142868

# %% [markdown]
# Compute the **skewness** and **kurtosis**

# %%
skewness = stats.skew(samples)
print("Skewness :", skewness)

kurtosis = stats.kurtosis(samples)
print("Kurtosis :", kurtosis)
# Out:
# Skewness : -0.03430500790409727
# Kurtosis : -0.008988956057560227

# %% [markdown]
# ## NumPy Correlation Calculation

# %% [markdown]
# Create an array x of integers between 10 (inclusive) and 20 (exclusive). Use `np.arange()`

# %%
x =

# %% [markdown]
# Then use `np.array()` to create a second array y containing 10 arbitrary integers.

# %%
y =

# %% [markdown]
# Once you have two arrays of the same length, you can compute the **correlation coefficient** between x and y

# %%
r =

# %% [markdown]
# ## Pandas Correlation Calculation

# %% [markdown]
# Run the code below

# %%
x = pd.Series(range(10, 20))
y = pd.Series([2, 1, 4, 5, 8, 12, 18, 25, 96, 48])

# %% [markdown]
# Call the relevant method  to calculate Pearson's r correlation.

# %%
r =

# %% [markdown]
# OPTIONAL. Call the relevant method to calculate Spearman's rho correlation.

# %%
rho =

# %% [markdown]
# ## Seaborn Dataset Tips

# %% [markdown]
# Import Seaborn Library

# %%
import

# %% [markdown]
# Load "tips" dataset from Seaborn

# %%
tips = sns.load_dataset("tips")

# %% [markdown]
# Generate descriptive statistics include those that summarize the central tendency, dispersion

# %% [markdown]
# Call the relevant method to calculate pairwise Pearson's r correlation of columns
